# %% [markdown]
# <a href="https://colab.research.google.com/github/manasdhir/recommendation-systems/blob/main/item_based_collaborative_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3156225 sha256=1c9942fc272a4373c84442aac7bd88a518919b2f606f8c5d9cbe0a0f0116e716
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# ...

# %%
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split

# %%
# Load the movielens-100k dataset  UserID::MovieID::Rating::Timestamp
data = Dataset.load_builtin('ml-100k')
trainset, testset = train_test_split(data, test_size=.15)
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k

# %%
# Use user_based true/false to switch between user-based or item-based collaborative filtering
algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# run the trained model against the testset
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='804', iid='95', r_ui=2.0, est=4.300442298975722, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='332', iid='9', r_ui=4.0, est=4.602922966161299, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='871', iid='937', r_ui=3.0, est=3.3916278496409173, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='416', iid='812', r_ui=4.0, est=3.2684321371263128, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='711', iid='496', r_ui=5.0, est=4.135753003100266, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='753', iid='462', r_ui=4.0, est=3.601307444024315, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='406', iid='1194', r_ui=4.0, est=4.063488979071419, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='559', iid='70', r_ui=3.0, est=3.474326412326561, details={'actual_k': 28, 'was_impossible': False}),
# ...

# %%
# get RMSE
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 0.9049
# 0.904943439945186
