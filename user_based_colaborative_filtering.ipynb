# %% [markdown]
# <a href="https://colab.research.google.com/github/manasdhir/recommendation-systems/blob/main/user_based_colaborative_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install surprise
# Out:
# Collecting surprise
#   Downloading surprise-0.1-py2.py3-none-any.whl (1.8 kB)
# Collecting scikit-surprise (from surprise)
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.11.2)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3156244 sha256=501f9bc8eec8a452ef39152fad14bd568d73327372555a560c9f5127edfea78f
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.3 surprise-0.1

# %%
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split

# %%
# Load the movielens-100k dataset  UserID::MovieID::Rating::Timestamp
data = Dataset.load_builtin('ml-100k')
trainset, testset = train_test_split(data, test_size=.15)
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k

# %%
# Use user_based true/false to switch between user-based or item-based collaborative filtering
algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# we can now query for specific predicions
uid = str(196)  # raw user id
iid = str(302)  # raw item id

# %%
# get a prediction for specific users and items.
pred = algo.predict(uid, iid, verbose=True)
# Out:
# user: 196        item: 302        r_ui = None   est = 4.16   {'actual_k': 50, 'was_impossible': False}

# %%
# run the trained model against the testset
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='939', iid='258', r_ui=4.0, est=4.885634351589587, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='287', iid='742', r_ui=3.0, est=4.539115206504525, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='532', iid='267', r_ui=3.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='844', iid='144', r_ui=3.0, est=3.7389590347794743, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='848', iid='509', r_ui=4.0, est=4.557600536439233, details={'actual_k': 44, 'was_impossible': False}),
#  Prediction(uid='501', iid='294', r_ui=3.0, est=3.5978792624658533, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='26', iid='760', r_ui=1.0, est=2.1307721055313613, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='447', iid='474', r_ui=3.0, est=4.302705712988694, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='905', iid='717', r_ui=1.0, est=2.359700380660891, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='102', iid='734', r_ui=2.0, est=1.4850754919519507, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='749', iid='100', r_ui=3.0, est=4.112661744230044, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='663', iid='844', r_ui=2.0, est=3.233359087912622, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='454', iid='277', r_ui=2.0, est=3.057619454901347, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='182', iid='257', r_ui=3.0, est=4.249598216436983, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='89', iid='707', r_ui=5.0, est=4.562760953715823, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='374', iid='454', r_ui=4.0, est=3.158425773260184, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='345', iid='461', r_ui=3.0, est=3.6311191074737477, details={'actual_k': 43, 'was_impossible': False}),
#  Prediction(uid='56', iid='235', r_ui=1.0, est=3.1307552320453045, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='495', iid='432', r_ui=5.0, est=4.073931222873391, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='16', iid='300', r_ui=5.0, est=4.426057483932611, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='135', iid='642', r_ui=4.0, est=3.748203549176182, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='706', iid='181', r_ui=4.0, est=4.149015260213711, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='848', iid='118', r_ui=2.0, est=4.148705758305054, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='327', iid='686', r_ui=4.0, est=3.267843863367068, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='158', iid='450', r_ui=3.0, est=2.5522566828465196, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='291', iid='385', r_ui=4.0, est=3.5850259201243477, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='526', iid='282', r_ui=3.0, est=3.2300935506137933, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='533', iid='15', r_ui=4.0, est=3.6592573392569596, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='642', iid='432', r_ui=2.0, est=3.6203335768687634, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='246', iid='80', r_ui=2.0, est=2.3070654411594043, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='894', iid='26', r_ui=4.0, est=3.4353023873104434, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='236', iid='134', r_ui=4.0, est=4.087481544342672, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='345', iid='708', r_ui=3.0, est=3.549007569463911, details={'actual_k': 49, 'was_impossible': False}),
#  Prediction(uid='22', iid='201', r_ui=4.0, est=3.4631980071682604, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='1', iid='236', r_ui=4.0, est=3.7755681067918343, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='524', iid='836', r_ui=2.0, est=3.3763472559597405, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='655', iid='1646', r_ui=3.0, est=2.901006711409396, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='836', iid='750', r_ui=3.0, est=4.363085925707718, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='854', iid='925', r_ui=2.0, est=2.6564790950893813, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='847', iid='257', r_ui=3.0, est=3.5051421562826257, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='878', iid='739', r_ui=3.0, est=3.0001196370026175, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='450', iid='302', r_ui=5.0, est=4.516081038028807, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='406', iid='148', r_ui=3.0, est=2.8543219909011586, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='561', iid='478', r_ui=4.0, est=3.4421346799947177, details={'actual_k': 44, 'was_impossible': False}),
#  Prediction(uid='374', iid='1010', r_ui=5.0, est=3.069044896035776, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='605', iid='301', r_ui=3.0, est=3.5401014067859613, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='13', iid='488', r_ui=3.0, est=3.8106344757647026, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='10', iid='651', r_ui=4.0, est=4.8146714624967375, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='807', iid='428', r_ui=4.0, est=4.330178594608432, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='887', iid='1473', r_ui=1.0, est=3.8576881216848573, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='472', iid='477', r_ui=5.0, est=3.8949516303838667, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='191', iid='900', r_ui=4.0, est=3.7192764903984346, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='721', iid='358', r_ui=1.0, est=2.908022356916603, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='201', iid='28', r_ui=3.0, est=3.142969253963095, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='115', iid='762', r_ui=4.0, est=3.785684138487588, details={'actual_k': 44, 'was_impossible': False}),
#  Prediction(uid='627', iid='550', r_ui=1.0, est=2.8455661869294673, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='305', iid='207', r_ui=5.0, est=3.778093555081554, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='363', iid='216', r_ui=3.0, est=3.425440671255672, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='329', iid='169', r_ui=4.0, est=4.195989912151391, details={'actual_k': 47, 'was_impossible': False}),
#  Prediction(uid='218', iid='431', r_ui=3.0, est=3.575662631077193, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='268', iid='479', r_ui=4.0, est=3.659443633862982, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='468', iid='294', r_ui=3.0, est=3.2765122671248035, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='476', iid='238', r_ui=3.0, est=3.8658548337078935, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='43', iid='254', r_ui=3.0, est=2.713169586692657, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='213', iid='357', r_ui=5.0, est=4.933912337585387, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='416', iid='43', r_ui=1.0, est=3.4559834539634906, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='846', iid='586', r_ui=2.0, est=2.8457988987768177, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='2', iid='287', r_ui=3.0, est=3.8173579625871263, details={'actual_k': 42, 'was_impossible': False}),
#  Prediction(uid='648', iid='79', r_ui=5.0, est=4.038313863631182, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='923', iid='273', r_ui=5.0, est=4.455262429220911, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='819', iid='321', r_ui=4.0, est=3.463278503153198, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='756', iid='550', r_ui=2.0, est=3.1632188319984627, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='587', iid='294', r_ui=3.0, est=2.805913460449605, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='500', iid='421', r_ui=4.0, est=3.4415938784525717, details={'actual_k': 42, 'was_impossible': False}),
#  Prediction(uid='564', iid='289', r_ui=4.0, est=2.82908814916247, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='435', iid='127', r_ui=4.0, est=4.186844749719832, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='798', iid='1270', r_ui=3.0, est=2.9886379778146455, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='435', iid='338', r_ui=2.0, est=2.723499891934135, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='877', iid='60', r_ui=5.0, est=4.19900220234642, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='758', iid='629', r_ui=4.0, est=3.6771522638158, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='652', iid='328', r_ui=4.0, est=3.138335092291929, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='1', iid='40', r_ui=3.0, est=3.0130353475282634, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='200', iid='931', r_ui=3.0, est=2.628136622177105, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='223', iid='11', r_ui=3.0, est=3.5257337906201367, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='13', iid='472', r_ui=5.0, est=2.5073609862263253, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='11', iid='372', r_ui=4.0, est=3.7849762696391065, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='692', iid='238', r_ui=4.0, est=3.4688711853883696, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='85', iid='657', r_ui=4.0, est=4.312277436744278, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='426', iid='427', r_ui=5.0, est=4.583711124429294, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='234', iid='73', r_ui=2.0, est=2.8946024926758858, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='837', iid='472', r_ui=3.0, est=2.629015615327182, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='253', iid='183', r_ui=5.0, est=4.2338326590213535, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='365', iid='277', r_ui=4.0, est=3.295335589256934, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='639', iid='323', r_ui=1.0, est=1.9501278071560757, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='65', iid='69', r_ui=3.0, est=4.5256090811394865, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='363', iid='919', r_ui=5.0, est=3.5230804524584327, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid='619', iid='288', r_ui=3.0, est=3.562200730720208, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='664', iid='514', r_ui=5.0, est=4.204922746308885, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='734', iid='132', r_ui=3.0, est=4.267374948697745, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='782', iid='905', r_ui=4.0, est=2.8266186472333414, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='743', iid='269', r_ui=4.0, est=4.102502282068539, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='286', iid='462', r_ui=5.0, est=4.008588042993336, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='275', iid='432', r_ui=4.0, est=3.5138309817504725, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='37', iid='174', r_ui=5.0, est=4.440211420538886, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='604', iid='448', r_ui=5.0, est=2.9501263476552375, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='150', iid='475', r_ui=5.0, est=4.376233785208899, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='213', iid='48', r_ui=5.0, est=4.7803996421594555, details={'actual_k': 49, 'was_impossible': False}),
#  Prediction(uid='167', iid='1306', r_ui=5.0, est=3.529329411764706, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='168', iid='619', r_ui=3.0, est=3.2693319390659537, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='712', iid='202', r_ui=4.0, est=4.151743639338588, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='698', iid='1021', r_ui=1.0, est=3.1018019852155185, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='916', iid='737', r_ui=3.0, est=3.240525083504078, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='689', iid='298', r_ui=4.0, est=4.2236795197168355, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='919', iid='815', r_ui=2.0, est=3.1991365151436715, details={'actual_k': 45, 'was_impossible': False}),
#  Prediction(uid='249', iid='919', r_ui=5.0, est=4.664270515581254, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='751', iid='111', r_ui=3.0, est=3.3405396202720716, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='417', iid='230', r_ui=3.0, est=3.373129499858685, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='826', iid='195', r_ui=5.0, est=4.424580783043918, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='629', iid='182', r_ui=5.0, est=4.794559676722995, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='866', iid='344', r_ui=2.0, est=3.019244875193226, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='537', iid='230', r_ui=2.0, est=2.4685912576340368, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='697', iid='369', r_ui=5.0, est=2.902481697963145, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='263', iid='678', r_ui=2.0, est=2.8700639167632715, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='353', iid='270', r_ui=2.0, est=3.7230583949115625, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='145', iid='770', r_ui=1.0, est=3.458945287151949, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='863', iid='333', r_ui=5.0, est=3.6015981926886678, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='661', iid='97', r_ui=4.0, est=4.094912214602087, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='405', iid='170', r_ui=1.0, est=2.4162121399149044, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid='486', iid='597', r_ui=3.0, est=2.8496801308700888, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='833', iid='98', r_ui=3.0, est=3.747093564546758, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='871', iid='270', r_ui=5.0, est=3.735918463856563, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='89', iid='952', r_ui=2.0, est=3.555068235101321, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='880', iid='346', r_ui=5.0, est=3.969886226317461, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='788', iid='58', r_ui=4.0, est=3.4327727086495092, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='426', iid='496', r_ui=3.0, est=4.464202211235889, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='99', iid='11', r_ui=5.0, est=4.38071115765709, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='232', iid='289', r_ui=4.0, est=3.5039788898307487, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='328', iid='498', r_ui=5.0, est=3.9446523516639838, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='843', iid='440', r_ui=1.0, est=2.0625101416723033, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='830', iid='205', r_ui=5.0, est=4.0918846060869765, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='514', iid='1600', r_ui=4.0, est=4.0474269649187145, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='280', iid='586', r_ui=4.0, est=2.9617347398216562, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='291', iid='5', r_ui=5.0, est=3.241862673372474, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='617', iid='443', r_ui=4.0, est=2.9647378010093846, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='184', iid='7', r_ui=3.0, est=4.030242360059018, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='781', iid='127', r_ui=5.0, est=4.600958359282689, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='561', iid='24', r_ui=3.0, est=2.9970605310412575, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='806', iid='96', r_ui=5.0, est=3.9852031723630135, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='825', iid='12', r_ui=5.0, est=4.2379690471958025, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='427', iid='303', r_ui=5.0, est=4.570744204415442, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid='516', iid='250', r_ui=4.0, est=4.165164252650287, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='919', iid='310', r_ui=3.0, est=3.3766681049113116, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='804', iid='748', r_ui=4.0, est=3.671180097466925, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='892', iid='184', r_ui=4.0, est=4.091197535581813, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid='872', iid='926', r_ui=4.0, est=2.812585842977995, details={'actual_k': 43, 'was_impossible': False}),
#  Prediction(uid='456', iid='402', r_ui=2.0, est=2.9856781028083064, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='838', iid='254', r_ui=3.0, est=3.1630598188955927, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='223', iid='1052', r_ui=1.0, est=2.3220952961271792, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='835', iid='427', r_ui=4.0, est=4.943868923049742, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='203', iid='93', r_ui=4.0, est=3.4183831219120706, details={'actual_k': 44, 'was_impossible': False}),
#  Prediction(uid='90', iid='155', r_ui=5.0, est=3.801118887643219, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='393', iid='270', r_ui=5.0, est=3.73294464932413, details={'actual_k': 49, 'was_impossible': False}),
#  Prediction(uid='177', iid='693', r_ui=4.0, est=4.1804866426132605, details={'actual_k': 45, 'was_impossible': False}),
#  Prediction(uid='13', iid='403', r_ui=2.0, est=2.9603933020106044, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='102', iid='393', r_ui=3.0, est=2.734853004086127, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='391', iid='471', r_ui=2.0, est=3.940043498427932, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='913', iid='117', r_ui=1.0, est=3.7133004272854886, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='770', iid='1012', r_ui=5.0, est=4.237048483798589, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='164', iid='313', r_ui=5.0, est=5, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='535', iid='427', r_ui=4.0, est=4.543542868353181, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='145', iid='477', r_ui=2.0, est=2.8865339387707394, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid='859', iid='288', r_ui=4.0, est=3.927650429799581, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='453', iid='248', r_ui=4.0, est=3.6979864119242287, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='87', iid='477', r_ui=3.0, est=3.1907049958258407, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid='468', iid='39', r_ui=3.0, est=3.584343104056891, details={'actual_k': 43, 'was_impossible': False}),
#  Prediction(uid='938', iid='676', r_ui=3.0, est=3.1386230681568414, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='232', iid='81', r_ui=5.0, est=3.94846989274011, details={'actual_k': 43, 'was_impossible': False}),
#  Prediction(uid='854', iid='49', r_ui=4.0, est=2.810759665410573, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='230', iid='385', r_ui=1.0, est=4.142645750535061, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='790', iid='248', r_ui=4.0, est=3.218593187068881, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='209', iid='688', r_ui=1.0, est=1.7043623909483967, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='367', iid='250', r_ui=5.0, est=4.272935999417517, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='32', iid='246', r_ui=4.0, est=4.1065226283913026, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='327', iid='631', r_ui=3.0, est=3.5657519129587065, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='334', iid='72', r_ui=3.0, est=3.0140366919526755, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid='416', iid='77', r_ui=4.0, est=3.9932315766294457, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='943', iid='595', r_ui=2.0, est=2.9666460547893805, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='551', iid='4', r_ui=2.0, est=3.8912964718382677, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='704', iid='154', r_ui=3.0, est=3.9514180256298506, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='100', iid='326', r_ui=3.0, est=3.2868324629290515, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='320', iid='38', r_ui=4.0, est=3.1132041398191808, details={'actual_k': 47, 'was_impossible': False}),
#  Prediction(uid='747', iid='169', r_ui=5.0, est=4.604457280873745, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='858', iid='292', r_ui=3.0, est=3.165744137132484, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='542', iid='50', r_ui=4.0, est=4.202399028945428, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='143', iid='323', r_ui=3.0, est=3.5770349372848513, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='85', iid='8', r_ui=4.0, est=4.101822219702298, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='92', iid='961', r_ui=4.0, est=3.426307800754361, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='262', iid='1035', r_ui=3.0, est=2.716558215044583, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='368', iid='50', r_ui=4.0, est=4.237062701733036, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='398', iid='525', r_ui=3.0, est=3.901764477805912, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='110', iid='56', r_ui=1.0, est=3.510045526492302, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='455', iid='553', r_ui=3.0, est=3.1994420311297866, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='297', iid='154', r_ui=5.0, est=3.8113495688191428, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='842', iid='302', r_ui=5.0, est=4.330345102105698, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='554', iid='71', r_ui=4.0, est=3.91354033038409, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='731', iid='378', r_ui=1.0, est=3.8134424770411868, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid='94', iid='537', r_ui=4.0, est=4.441468156838604, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='233', iid='462', r_ui=5.0, est=4.5763260140691235, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='145', iid='242', r_ui=5.0, est=3.9100393983702055, details={'actual_k': 42, 'was_impossible': False}),
#  Prediction(uid='588', iid='83', r_ui=5.0, est=4.3812226860683126, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='554', iid='735', r_ui=3.0, est=3.891619503501879, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='916', iid='582', r_ui=4.0, est=3.7935089952539442, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='72', iid='1148', r_ui=4.0, est=3.8961065930060226, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='807', iid='28', r_ui=4.0, est=4.57256654290817, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='249', iid='421', r_ui=5.0, est=4.175396375273829, details={'actual_k': 49, 'was_impossible': False}),
#  Prediction(uid='495', iid='1469', r_ui=5.0, est=3.2246667235732582, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='395', iid='210', r_ui=5.0, est=4.164983125403571, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='776', iid='1219', r_ui=3.0, est=2.4087607666479496, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='222', iid='542', r_ui=2.0, est=1.8675575468994086, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='449', iid='639', r_ui=5.0, est=4.06897081281338, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='642', iid='231', r_ui=3.0, est=2.996217119556905, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='399', iid='155', r_ui=2.0, est=2.8598107441792635, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='90', iid='904', r_ui=3.0, est=4.683109119480959, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='437', iid='111', r_ui=3.0, est=3.4095767999079336, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='271', iid='866', r_ui=4.0, est=3.051721152417657, details={'actual_k': 45, 'was_impossible': False}),
#  Prediction(uid='269', iid='928', r_ui=1.0, est=2.2375246761993557, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='490', iid='100', r_ui=3.0, est=3.642532869115401, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='489', iid='874', r_ui=2.0, est=3.4752375068303087, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='932', iid='222', r_ui=4.0, est=3.6696486397739108, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='279', iid='685', r_ui=3.0, est=3.1459717893749866, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='269', iid='735', r_ui=2.0, est=3.3096772716775473, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='399', iid='462', r_ui=3.0, est=3.1797418904495056, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='130', iid='508', r_ui=4.0, est=3.779161772567118, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='405', iid='482', r_ui=3.0, est=2.2167437336923497, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid='426', iid='132', r_ui=4.0, est=4.3884737897175965, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='45', iid='926', r_ui=3.0, est=2.865408727220208, details={'actual_k': 45, 'was_impossible': False}),
#  Prediction(uid='880', iid='380', r_ui=3.0, est=2.8307360532494847, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6', iid='178', r_ui=4.0, est=4.554090471076463, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='346', iid='240', r_ui=1.0, est=2.665199420349128, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='378', iid='775', r_ui=3.0, est=2.395545367653415, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='178', iid='89', r_ui=4.0, est=4.1822482010307995, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='254', iid='389', r_ui=3.0, est=2.9079183977192393, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='207', iid='468', r_ui=4.0, est=3.240252256575394, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='26', iid='410', r_ui=2.0, est=2.634694686743044, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='474', iid='1134', r_ui=3.0, est=4.346248566351595, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='13', iid='540', r_ui=3.0, est=2.0979709117936927, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='561', iid='531', r_ui=1.0, est=3.360370694912191, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='894', iid='1080', r_ui=4.0, est=4.993709677419355, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='384', iid='989', r_ui=4.0, est=3.615283620761719, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='666', iid='480', r_ui=4.0, est=4.288810954257818, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='643', iid='1065', r_ui=4.0, est=4.120608692928877, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='183', iid='258', r_ui=3.0, est=3.4946287130826894, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='244', iid='301', r_ui=2.0, est=3.4059222441094104, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='659', iid='568', r_ui=4.0, est=4.1208547009587, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='196', iid='340', r_ui=3.0, est=3.7076512673082984, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='342', iid='262', r_ui=2.0, est=4.013729810197453, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='257', iid='1472', r_ui=2.0, est=3.9791666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='405', iid='939', r_ui=5.0, est=1.6752726413367027, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='92', iid='845', r_ui=3.0, est=2.9913822725871677, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='825', iid='290', r_ui=4.0, est=3.5001101631214135, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='331', iid='634', r_ui=3.0, est=3.9787138824235386, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='299', iid='522', r_ui=3.0, est=4.163683637633222, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='233', iid='117', r_ui=3.0, est=4.770351268096583, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='454', iid='1', r_ui=3.0, est=3.5639184813610765, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='392', iid='312', r_ui=4.0, est=3.4872837325019215, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='924', iid='433', r_ui=5.0, est=3.6378890977618994, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='291', iid='1277', r_ui=4.0, est=3.5327581336667637, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='663', iid='833', r_ui=4.0, est=3.2844867810991993, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='758', iid='82', r_ui=4.0, est=3.884283991457087, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='745', iid='14', r_ui=3.0, est=3.288113433097141, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='537', iid='202', r_ui=3.0, est=2.8431333469224795, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='497', iid='167', r_ui=2.0, est=2.7728288588900356, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='666', iid='499', r_ui=4.0, est=3.970096112710147, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='661', iid='79', r_ui=5.0, est=4.395439955001882, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='523', iid='166', r_ui=4.0, est=4.959368178077362, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='716', iid='31', r_ui=3.0, est=3.841148342347912, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='13', iid='524', r_ui=4.0, est=3.460268403323891, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='349', iid='106', r_ui=1.0, est=2.4551389246662705, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='504', iid='1046', r_ui=4.0, est=3.3984268270582803, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='303', iid='575', r_ui=4.0, est=2.5517504033180973, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='406', iid='1202', r_ui=3.0, est=4.2900745783850285, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='809', iid='299', r_ui=4.0, est=3.1678830923257646, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='916', iid='215', r_ui=3.0, est=3.4035026822452363, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='942', iid='234', r_ui=4.0, est=4.547261704090242, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='13', iid='674', r_ui=3.0, est=2.5730077518578143, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='569', iid='7', r_ui=4.0, est=3.6106360975629954, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='657', iid='508', r_ui=4.0, est=3.3947904124717576, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='524', iid='1041', r_ui=2.0, est=2.538148462760383, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='454', iid='285', r_ui=2.0, est=3.404895678990874, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='5', iid='379', r_ui=3.0, est=2.415372194126827, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='782', iid='343', r_ui=2.0, est=2.5295420179434376, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='761', iid='283', r_ui=4.0, est=3.0167375942989465, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='268', iid='506', r_ui=4.0, est=3.313556928494113, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid='221', iid='222', r_ui=3.0, est=3.5996625045046975, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='655', iid='468', r_ui=3.0, est=2.5511810328528837, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='332', iid='369', r_ui=4.0, est=3.538181631429204, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='213', iid='258', r_ui=4.0, est=4.619159533340216, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='128', iid='82', r_ui=5.0, est=3.8920716092940366, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='394', iid='928', r_ui=4.0, est=3.4224330085147616, details={'actual_k': 49, 'was_impossible': False}),
#  Prediction(uid='887', iid='50', r_ui=5.0, est=4.7872023627283715, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='442', iid='7', r_ui=4.0, est=3.5954689857821265, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='396', iid='930', r_ui=3.0, est=2.9954721081240425, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='213', iid='447', r_ui=4.0, est=4.230072190378462, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='721', iid='380', r_ui=5.0, est=3.845219224700533, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid='334', iid='47', r_ui=4.0, est=3.630708207647296, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='846', iid='659', r_ui=5.0, est=4.102774126122417, details={'actual_k': 47, 'was_impossible': False}),
#  Prediction(uid='305', iid='961', r_ui=3.0, est=3.568128943947609, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='437', iid='145', r_ui=1.0, est=2.4319354494967262, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='138', iid='435', r_ui=5.0, est=4.483111489011998, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='484', iid='186', r_ui=4.0, est=4.302185072782183, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='44', iid='31', r_ui=4.0, est=3.4220421056157675, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='741', iid='226', r_ui=2.0, est=3.299778370285156, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='432', iid='508', r_ui=5.0, est=3.7145090000807444, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='326', iid='468', r_ui=3.0, est=3.5740659813200812, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='307', iid='427', r_ui=3.0, est=4.53555645759279, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='780', iid='520', r_ui=4.0, est=4.595107763141516, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='293', iid='412', r_ui=1.0, est=2.3157437434350605, details={'actual_k': 43, 'was_impossible': False}),
#  Prediction(uid='303', iid='121', r_ui=3.0, est=2.8700816298847833, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='746', iid='523', r_ui=3.0, est=3.9437291701199286, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='759', iid='245', r_ui=3.0, est=4.088032060919001, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='268', iid='790', r_ui=2.0, est=2.6695288365822423, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='774', iid='452', r_ui=1.0, est=1.045811230823459, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='746', iid='62', r_ui=3.0, est=3.344906477087362, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='407', iid='181', r_ui=3.0, est=3.926049840455856, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='429', iid='81', r_ui=3.0, est=3.653383673497311, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='208', iid='197', r_ui=5.0, est=4.4380031974444645, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='666', iid='370', r_ui=2.0, est=2.685480449477632, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='187', iid='179', r_ui=5.0, est=4.524249750023017, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='58', iid='182', r_ui=4.0, est=4.5845453874127875, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='355', iid='682', r_ui=4.0, est=3.9051868081057863, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='458', iid='823', r_ui=3.0, est=3.111340567050568, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='20', iid='181', r_ui=4.0, est=3.5848176743576676, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='74', iid='288', r_ui=3.0, est=3.7391664690140014, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='774', iid='318', r_ui=1.0, est=2.700067624630317, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='454', iid='434', r_ui=3.0, est=3.323000610743779, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='514', iid='658', r_ui=4.0, est=3.9947408026074447, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='382', iid='235', r_ui=5.0, est=2.8403125501452413, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='453', iid='423', r_ui=4.0, est=3.355359841042939, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='629', iid='238', r_ui=5.0, est=4.313397459985099, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='499', iid='1483', r_ui=1.0, est=4.0346331789523795, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='405', iid='644', r_ui=3.0, est=2.195152548542978, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='813', iid='270', r_ui=5.0, est=3.1592026053874154, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid='887', iid='252', r_ui=4.0, est=3.073015084300236, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='451', iid='1025', r_ui=3.0, est=2.4578283072026075, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='276', iid='219', r_ui=4.0, est=3.677471848104121, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='142', iid='186', r_ui=4.0, est=3.867949032053765, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='587', iid='243', r_ui=3.0, est=1.8158331918205046, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='871', iid='333', r_ui=2.0, est=3.9045702932660427, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='422', iid='15', r_ui=3.0, est=3.772653873468743, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='407', iid='474', r_ui=3.0, est=4.256092454221512, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='741', iid='98', r_ui=5.0, est=4.390898685450247, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='340', iid='71', r_ui=5.0, est=4.586763927096822, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='235', iid='483', r_ui=5.0, est=4.716159486429256, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='416', iid='990', r_ui=2.0, est=3.125228479534983, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='283', iid='21', r_ui=3.0, est=3.771034363810922, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='779', iid='121', r_ui=3.0, est=4.506614293116933, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='664', iid='194', r_ui=4.0, est=4.155772323795179, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='60', iid='69', r_ui=4.0, est=3.9746806938815706, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='5', iid='437', r_ui=1.0, est=1, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='788', iid='723', r_ui=3.0, est=2.956757955967124, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='303', iid='1210', r_ui=1.0, est=2.79701949372369, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='383', iid='86', r_ui=5.0, est=4.637705020753584, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='345', iid='1016', r_ui=3.0, est=3.5155390970572884, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='896', iid='508', r_ui=2.0, est=2.9055816603779094, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='624', iid='333', r_ui=4.0, est=3.720723834700536, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='393', iid='597', r_ui=3.0, est=3.212977754417812, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='394', iid='496', r_ui=5.0, est=4.196768371126092, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='318', iid='127', r_ui=5.0, est=4.245270248774279, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='747', iid='664', r_ui=2.0, est=4.265962625506097, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='602', iid='9', r_ui=4.0, est=4.031068733703969, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='486', iid='146', r_ui=2.0, est=2.5342486119176897, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='387', iid='239', r_ui=1.0, est=3.2976460365695766, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='545', iid='25', r_ui=2.0, est=3.465945948527955, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='130', iid='769', r_ui=3.0, est=2.920107835582921, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='313', iid='28', r_ui=3.0, est=3.808058300344291, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='445', iid='293', r_ui=3.0, est=2.394929570749908, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='151', iid='971', r_ui=5.0, est=4.431540763207114, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='336', iid='1012', r_ui=5.0, est=2.9243159078433982, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='412', iid='195', r_ui=4.0, est=4.4925319866449325, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='59', iid='81', r_ui=4.0, est=3.8327021250229993, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='200', iid='99', r_ui=5.0, est=4.244021349726108, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='256', iid='471', r_ui=5.0, est=4.1593948033614065, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='318', iid='237', r_ui=5.0, est=3.616456776272433, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='193', iid='258', r_ui=3.0, est=3.5131055631109573, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='130', iid='532', r_ui=5.0, est=3.1004170042152923, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='403', iid='471', r_ui=5.0, est=4.036203470902131, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='514', iid='136', r_ui=4.0, est=4.222155953170736, details={'actual_k': 42, 'was_impossible': False}),
#  Prediction(uid='354', iid='496', r_ui=3.0, est=4.0734810631496, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='75', iid='460', r_ui=5.0, est=2.935537607743144, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='104', iid='1010', r_ui=1.0, est=2.4607567149300706, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='537', iid='528', r_ui=3.0, est=3.4836916637763027, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='758', iid='137', r_ui=5.0, est=4.416010983348991, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='897', iid='121', r_ui=5.0, est=4.505860580792369, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='870', iid='647', r_ui=4.0, est=3.835295539140309, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='217', iid='222', r_ui=5.0, est=2.835949493326426, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='442', iid='229', r_ui=3.0, est=2.7715277834995558, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='286', iid='345', r_ui=4.0, est=3.5656301636422336, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='393', iid='283', r_ui=3.0, est=3.473499124936503, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='880', iid='24', r_ui=3.0, est=3.625279664135153, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='833', iid='118', r_ui=2.0, est=2.243683252100603, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='668', iid='354', r_ui=4.0, est=3.064113662274481, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='95', iid='190', r_ui=4.0, est=3.8206661231736785, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid='784', iid='898', r_ui=4.0, est=3.4162397680957826, details={'actual_k': 22, 'was_impossible': False}),
# ...
#  Prediction(uid='56', iid='281', r_ui=2.0, est=3.4556419942963306, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='880', iid='1157', r_ui=4.0, est=2.2216115290925007, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='537', iid='321', r_ui=3.0, est=2.6840114641585933, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='301', iid='334', r_ui=3.0, est=3.183648187591912, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='905', iid='326', r_ui=3.0, est=3.1638540496617527, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='9', iid='402', r_ui=4.0, est=4.229188651652468, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='292', iid='100', r_ui=5.0, est=5, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='494', iid='64', r_ui=5.0, est=5, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='887', iid='418', r_ui=4.0, est=4.0779583548353235, details={'actual_k': 44, 'was_impossible': False}),
#  Prediction(uid='92', iid='143', r_ui=3.0, est=3.1098717174665564, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='532', iid='332', r_ui=4.0, est=4.131734861583761, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='218', iid='42', r_ui=4.0, est=3.7784933091324704, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='831', iid='340', r_ui=4.0, est=3.4498771396603356, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='327', iid='475', r_ui=4.0, est=3.773891137289186, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='254', iid='432', r_ui=2.0, est=3.3744880847584673, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='301', iid='96', r_ui=5.0, est=4.214774965308525, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='634', iid='21', r_ui=2.0, est=2.8721342477124763, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='715', iid='64', r_ui=5.0, est=4.598854008774201, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='301', iid='743', r_ui=2.0, est=1.9360053763601288, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='788', iid='194', r_ui=4.0, est=3.463306687890125, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='381', iid='778', r_ui=4.0, est=3.890726510823802, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid='653', iid='211', r_ui=1.0, est=3.029202997835849, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='880', iid='396', r_ui=2.0, est=3.0633141408795597, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='416', iid='510', r_ui=4.0, est=4.3489661720085815, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='1', iid='34', r_ui=2.0, est=1.9546241257826111, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='523', iid='194', r_ui=5.0, est=4.969711837483431, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='293', iid='195', r_ui=3.0, est=3.410878975489833, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='360', iid='496', r_ui=3.0, est=4.416969193432686, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='453', iid='393', r_ui=3.0, est=2.98157687270244, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='57', iid='744', r_ui=5.0, est=3.2266300123175657, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='280', iid='1060', r_ui=3.0, est=3.4301516405462973, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='178', iid='469', r_ui=3.0, est=3.6999118257848784, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='283', iid='866', r_ui=3.0, est=3.8173456156172154, details={'actual_k': 45, 'was_impossible': False}),
#  Prediction(uid='43', iid='423', r_ui=4.0, est=4.179415688798932, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='425', iid='912', r_ui=2.0, est=3.131376181223495, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='101', iid='1132', r_ui=3.0, est=1.9548584901218002, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='39', iid='294', r_ui=4.0, est=3.3632001911566194, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='359', iid='455', r_ui=4.0, est=3.8048301948611383, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='378', iid='1311', r_ui=4.0, est=2.299748165999832, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='704', iid='1454', r_ui=3.0, est=3.1637180443443196, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='907', iid='129', r_ui=5.0, est=4.872592316095432, details={'actual_k': 45, 'was_impossible': False}),
#  Prediction(uid='125', iid='88', r_ui=5.0, est=3.565031668695565, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='620', iid='243', r_ui=3.0, est=2.8601114171770052, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='138', iid='26', r_ui=5.0, est=4.377526406335588, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='294', iid='472', r_ui=3.0, est=2.955855894409945, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='747', iid='83', r_ui=4.0, est=4.421125882536965, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='145', iid='1132', r_ui=3.0, est=2.735431624272211, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='459', iid='336', r_ui=2.0, est=2.9208350124931783, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='561', iid='214', r_ui=3.0, est=3.038678046410832, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='790', iid='154', r_ui=4.0, est=3.2408392966806425, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='94', iid='399', r_ui=4.0, est=3.1354881116186175, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='57', iid='864', r_ui=3.0, est=3.1496311160295645, details={'actual_k': 43, 'was_impossible': False}),
#  Prediction(uid='91', iid='264', r_ui=4.0, est=3.1735585375654587, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='57', iid='323', r_ui=3.0, est=3.172966425695391, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='281', iid='310', r_ui=4.0, est=3.5779738799451852, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='268', iid='95', r_ui=4.0, est=2.958406420279574, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='774', iid='82', r_ui=2.0, est=2.1428809114370044, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='357', iid='760', r_ui=3.0, est=3.2228143542594685, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='253', iid='82', r_ui=3.0, est=4.399707771338616, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='586', iid='410', r_ui=3.0, est=3.096998810662742, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='7', iid='39', r_ui=5.0, est=3.8650086357307605, details={'actual_k': 43, 'was_impossible': False}),
#  Prediction(uid='380', iid='708', r_ui=3.0, est=2.938121281212951, details={'actual_k': 43, 'was_impossible': False}),
#  Prediction(uid='815', iid='98', r_ui=4.0, est=4.585719304155173, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='818', iid='322', r_ui=2.0, est=2.508788323182677, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='592', iid='81', r_ui=4.0, est=4.121339872706111, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='393', iid='820', r_ui=3.0, est=2.7483883778697766, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='924', iid='12', r_ui=4.0, est=4.433314537841221, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='181', iid='887', r_ui=1.0, est=1.9506830281848573, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='661', iid='210', r_ui=5.0, est=4.3640269975802335, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='576', iid='323', r_ui=3.0, est=3.2211264627503553, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='385', iid='180', r_ui=4.0, est=3.8275026005530632, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='379', iid='528', r_ui=5.0, est=4.47610839266428, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='417', iid='1', r_ui=4.0, est=3.424900278381303, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='806', iid='483', r_ui=4.0, est=4.536710097044003, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='653', iid='223', r_ui=3.0, est=3.437888668193301, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='500', iid='662', r_ui=2.0, est=3.0058787406176526, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='864', iid='755', r_ui=4.0, est=3.6644357263620053, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid='214', iid='313', r_ui=4.0, est=4.292637048289571, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='837', iid='20', r_ui=4.0, est=3.3919436783926282, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='758', iid='319', r_ui=4.0, est=3.7015070523077465, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='450', iid='422', r_ui=3.0, est=3.3392099724037, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='193', iid='580', r_ui=4.0, est=2.9700691726315434, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='537', iid='1085', r_ui=4.0, est=2.607369227270222, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='724', iid='313', r_ui=5.0, est=3.190886507611049, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='10', iid='664', r_ui=4.0, est=4.114266716601819, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='59', iid='241', r_ui=4.0, est=3.779735745481464, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='85', iid='921', r_ui=3.0, est=4.044356435475857, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='215', iid='176', r_ui=5.0, est=4.0943452736667325, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='308', iid='618', r_ui=4.0, est=3.557691541590424, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='877', iid='531', r_ui=5.0, est=4.005363270278026, details={'actual_k': 41, 'was_impossible': False}),
#  Prediction(uid='641', iid='50', r_ui=3.0, est=4.738033357024082, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='254', iid='393', r_ui=3.0, est=3.03408771201506, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='847', iid='240', r_ui=1.0, est=2.1323839356063337, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='308', iid='482', r_ui=5.0, est=4.214947548173274, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid='291', iid='100', r_ui=5.0, est=4.710082334695589, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='76', iid='70', r_ui=4.0, est=3.7417827585851176, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='533', iid='291', r_ui=3.0, est=3.6740488122045942, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='381', iid='473', r_ui=5.0, est=3.8559913771507857, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='320', iid='147', r_ui=4.0, est=3.8928941439690887, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='125', iid='657', r_ui=3.0, est=3.986461928027017, details={'actual_k': 45, 'was_impossible': False}),
#  Prediction(uid='690', iid='742', r_ui=3.0, est=3.414327861600253, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='474', iid='58', r_ui=4.0, est=4.082409672554777, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='923', iid='928', r_ui=4.0, est=3.804715845958811, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='833', iid='928', r_ui=2.0, est=2.6683360978729103, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='312', iid='609', r_ui=3.0, est=4.37951073383272, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='268', iid='51', r_ui=3.0, est=2.7107747950411967, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='343', iid='250', r_ui=5.0, est=4.017307374065311, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='474', iid='170', r_ui=4.0, est=4.868376327615051, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='833', iid='512', r_ui=4.0, est=3.7572136026878944, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='104', iid='330', r_ui=1.0, est=2.35655928577657, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='682', iid='56', r_ui=4.0, est=3.623801473871391, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='756', iid='222', r_ui=2.0, est=3.357365113896856, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='22', iid='226', r_ui=4.0, est=3.2229834237184853, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='932', iid='489', r_ui=4.0, est=4.367419714943237, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='912', iid='616', r_ui=3.0, est=3.8934516899322467, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='221', iid='150', r_ui=5.0, est=3.8922816196476253, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='109', iid='248', r_ui=2.0, est=3.4540207951475974, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='237', iid='483', r_ui=5.0, est=4.9706166902521876, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='414', iid='346', r_ui=5.0, est=4.097276751350307, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='160', iid='11', r_ui=4.0, est=4.401098532196555, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='145', iid='23', r_ui=4.0, est=3.796024720094071, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='440', iid='921', r_ui=5.0, est=4.671623760802526, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='379', iid='270', r_ui=3.0, est=3.9817693207189393, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='934', iid='228', r_ui=4.0, est=3.9610239686675333, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='862', iid='515', r_ui=4.0, est=4.869403280609504, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='324', iid='50', r_ui=5.0, est=5, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='583', iid='83', r_ui=4.0, est=4.824613804360839, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='848', iid='209', r_ui=5.0, est=4.332613421894217, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='889', iid='13', r_ui=4.0, est=3.3546374305667195, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='751', iid='300', r_ui=2.0, est=3.6233463997855635, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='561', iid='371', r_ui=1.0, est=2.760816563642786, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='423', iid='348', r_ui=3.0, est=2.98064685057688, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='488', iid='239', r_ui=4.0, est=3.5288885376035184, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='313', iid='435', r_ui=5.0, est=3.962298783879329, details={'actual_k': 50, 'was_impossible': False}),
#  ...]

# %%
# get RMSE
print("User-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# User-based Model : Test Set
# RMSE: 0.9339
# 0.9338619899361652
